# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthika1915/certificateverification/blob/main/Supervisied.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd#data manipulation
import numpy as np#array operation
df=pd.read_csv("/content/Salary Data (2).csv")
df.head(3)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0

# %%
import plotly.express as px
px.scatter(df,x=["Age"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#duplicates
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df.drop_duplicates(inplace=True)

# %%
#duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#detection
df#duplicates
df.isnull().sum()
# Out:
# Age                    1
# Gender                 1
# Education Level        1
# Job Title              1
# Years of Experience    1
# Salary                 1
# dtype: int64

# %%
import missingno as  msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df.fillna(df.mode().iloc[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
X=df.drop("Salary",axis=1)
y=df["Salary"]
y
# Out:
# 0       90000.0
# 1       65000.0
# 2      150000.0
# 3       60000.0
# 4      200000.0
#          ...
# 348     35000.0
# 349    110000.0
# 350    160000.0
# 351     55000.0
# 371    170000.0
# Name: Salary, Length: 325, dtype: float64

# %%
X.shape
# Out:
# (325, 181)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scler=StandardScaler()
X=scler.fit_transform(X)
X
# Out:
# array([[-0.75138772, -0.76299561, -0.94899146, ..., -0.05555556,
#         -0.05555556, -0.05555556],
#        [-1.30975841, -1.06465586,  1.05375026, ..., -0.05555556,
#         -0.05555556, -0.05555556],
#        [ 1.06331703,  0.74530565, -0.94899146, ..., -0.05555556,
#         -0.05555556, -0.05555556],
#        ...,
#        [ 0.92372435,  0.89613578,  1.05375026, ..., -0.05555556,
#         -0.05555556, -0.05555556],
#        [-0.89098039, -1.06465586, -0.94899146, ..., -0.05555556,
#         -0.05555556, -0.05555556],
#        [ 0.78413168,  1.34862616, -0.94899146, ..., -0.05555556,
#         -0.05555556, -0.05555556]])

# %%
X.shape
# Out:
# (325, 181)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
y_test.shape
# Out:
# (33,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([135243.80126617, 137916.95935098, 118225.29755086,  88106.51575767,
#         72094.29490384,  59413.69618682, 138646.53553991, 109193.75181171,
#         47260.03962377, 127845.76820807,  56301.57703867, 142800.45362611,
#        161572.09101026,  41236.22532756,  35000.        ,  81438.33268597,
#         62712.88632229,  49538.76464724,  95437.73260327,  81704.23677291,
#        115023.81861422,  79971.96843671, 143857.98906191,  39856.88447944,
#         28183.46783863,  88106.51575767,  74167.65712917,  34101.55537384,
#        131111.21700604,  89740.87200566,  83124.53911147, 112335.66190558,
#        162900.29854846])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8075039014562514

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(X_train,y_train)

# %%
import joblib
joblib.dump(model,"salark.pkl")
# Out:
# ['salark.pkl']
